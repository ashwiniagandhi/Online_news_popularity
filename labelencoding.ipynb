# %%
import numpy as np
import pandas as pd
from time import time
from IPython.display import display#allow the use of display()for dataframe

# %%
import matplotlib as plt
# %matplotlib inline

# %%
data=pd.read_csv("OnlineNewsPopularity.csv")
data
# Out:
#                                                      url   timedelta  \
# 0      http://mashable.com/2013/01/07/amazon-instant-...       731.0
# 1      http://mashable.com/2013/01/07/ap-samsung-spon...       731.0
# 2      http://mashable.com/2013/01/07/apple-40-billio...       731.0
# 3      http://mashable.com/2013/01/07/astronaut-notre...       731.0
# 4       http://mashable.com/2013/01/07/att-u-verse-apps/       731.0
# ...                                                  ...         ...
# 39639  http://mashable.com/2014/12/27/samsung-app-aut...         8.0
# 39640  http://mashable.com/2014/12/27/seth-rogen-jame...         8.0
# 39641  http://mashable.com/2014/12/27/son-pays-off-mo...         8.0
# 39642     http://mashable.com/2014/12/27/ukraine-blasts/         8.0
# 39643  http://mashable.com/2014/12/27/youtube-channel...         8.0
#
#         n_tokens_title   n_tokens_content   n_unique_tokens  \
# 0                 12.0              219.0          0.663594
# ...

# %%
data[' shares']
# Out:
# 0         593
# 1         711
# 2        1500
# 3        1200
# 4         505
#          ...
# 39639    1800
# 39640    1900
# 39641    1900
# 39642    1100
# 39643    1300
# Name:  shares, Length: 39644, dtype: int64

# %%
display(data.head())
# Out:
#                                                  url   timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...       731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...       731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...       731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...       731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/       731.0
#
#     n_tokens_title   n_tokens_content   n_unique_tokens   n_non_stop_words  \
# 0             12.0              219.0          0.663594                1.0
# 1              9.0              255.0          0.604743                1.0
# 2              9.0              211.0          0.575130                1.0
# 3              9.0              531.0          0.503788                1.0
# 4             13.0             1072.0          0.415646                1.0
#
#     n_non_stop_unique_tokens   num_hrefs   num_self_hrefs   num_imgs  ...  \
# ...

# %%
#get the statstics of original target attribute
popularity_raw=data[data.keys()[-1]]
popularity_raw.describe()
#encodethe labelby threshold 1400
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
popular_label=pd.Series(label_encoder.fit_transform(popularity_raw>=1400))

# %%
#Getting features(removing non predictive and target variables)
1.url of article and time delta(which is days between the article publication and dataset aquisition)were removed since these are non _predictive
features that were not used in prediction model 
2.target variable"shares"is also dropped .the databy removing above variables is set as fetures_raw

# %%
#get features from dataset
features_rows=data.drop(['url',data.keys()[1],data.keys()[-1]],axis=1)
display(features_rows.head())
# Out:
#     n_tokens_title   n_tokens_content   n_unique_tokens   n_non_stop_words  \
# 0             12.0              219.0          0.663594                1.0
# 1              9.0              255.0          0.604743                1.0
# 2              9.0              211.0          0.575130                1.0
# 3              9.0              531.0          0.503788                1.0
# 4             13.0             1072.0          0.415646                1.0
#
#     n_non_stop_unique_tokens   num_hrefs   num_self_hrefs   num_imgs  \
# 0                   0.815385         4.0              2.0        1.0
# 1                   0.791946         3.0              1.0        1.0
# 2                   0.663866         3.0              1.0        1.0
# 3                   0.665635         9.0              0.0        1.0
# 4                   0.540890        19.0             19.0       20.0
#
#     num_videos   average_token_length  ...   avg_positive_polarity  \
# ...

# %%
#finding threshold value for target variable

# %%
data[data.keys()[-1]].describe()
# Out:
# count     39644.000000
# mean       3395.380184
# std       11626.950749
# min           1.000000
# 25%         946.000000
# 50%        1400.000000
# 75%        2800.000000
# max      843300.000000
# Name:  shares, dtype: float64

# %%
Here 50% have value 1400 that means balanced classes.hence 1400 is choosen as threshold value for share variable.SHAREs>1400 are considered as
popular shares<=1400 are considered as unpopular

# %% [markdown]
# # Visualizing the feature of differeent day of week

# %%
weeked_is_monday.weekday_is_tuesday.weekday_is_wednesday.weekday_is_thursday.
weekday_is_friday.weekend_is_saturday
variable are visulaized with the help of matplotlib.popis the data where shares=>1400 threshold value unpop is the data where shares<1400threshold values

# %%
#visulize the feature of different day of week
columns_day=features_rows.columns.values[29:36]
unpop=data[data[' shares']<1400]
pop=data[data[' shares']>=1400]
unpop_day=unpop[columns_day].sum().values
pop_day=pop[columns_day].sum().values

# %%
import matplotlib as plt
from IPython import get_ipython
get_ipython().run_line_magic("matplotlib",'inline')

# %%
fig=plt.figure(figsize=(13,5))
plt.title("Count of popular/unpopularnews over different day of week",fontsize=16)
plt.bar(np.arange(len(columns_day)),pop_day,width=0.3,align='center',color='r',\label='popular')
# Out:
#   File "<ipython-input-43-f1ad6a51497b>", line 3
#     plt.bar(np.arange(len(columns_day)),pop_day,width=0.3,align='center',color='r',\label='popular')
#                                                                                                     ^
# SyntaxError: unexpected character after line continuation character

# %%
plt.bar(np.arange(len(columns_day))-0.3,unpop_day,width=0.3,align='centre',color='b',label='unpopular')
plt.xticks(np.arange(len(columns_day)),columns_day)
plt.ylabel('Count',fontsize=12)
plt.xlabel("Days of week",fontsize=12)
plt.legend(loc='upper right')
plt.tight_layout()
plt.savefig("pop_unpop_days.pdf")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-cdae3c711684> in <module>
# ----> 1 plt.bar(np.arange(len(columns_day))-0.3,unpop_day,width=0.3,align='centre',color='b',label='unpopular')
#       2 plt.xticks(np.arange(len(columns_day)),columns_day)
#       3 plt.ylabel('Count',fontsize=12)
#       4 plt.xlabel("Days of week",fontsize=12)
#       5 plt.legend(loc='upper right')
#
# AttributeError: module 'matplotlib' has no attribute 'bar'
